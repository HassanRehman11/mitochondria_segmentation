# %%
import os
import cv2
import numpy as np
from config import *
from utils import interpolate_image, DataGenerator, create_directory
import segmentation_models as sm
import tensorflow as tf
from tensorflow.keras import callbacks
from keras_visualizer import visualizer
# Out:
# Segmentation Models: using `keras` framework.

# %%
model_path = create_directory(["models"])
training_path = "DATA/compressed"
training_images = os.listdir(training_path)
training_images = [f"{training_path}/{e}" for e in training_images]
# Out:
# models already existed

# %%
train_data = DataGenerator(np.array(training_images),4)

# %%
sm.set_framework('tf.keras')
sm.framework()

model = sm.Unet(BACKBONE, classes=n_classes, activation=activation,
                input_shape=(input_images_size, input_images_size, 1),
                encoder_weights=learning_rate)
optim = tf.keras.optimizers.Adam(0.001)

dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.BinaryFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = [sm.metrics.IOUScore(threshold=0.5),
           sm.metrics.FScore(threshold=0.5)]

model.compile(optim, total_loss, metrics)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 384, 384, 1) 0
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 192, 192, 40) 360         input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 192, 192, 40) 160         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 192, 192, 40) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 192, 192, 40) 360         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 192, 192, 40) 160         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 192, 192, 40) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 40)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 40)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 10)     410         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 40)     440         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 192, 192, 40) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 192, 192, 24) 960         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 192, 192, 24) 96          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 192, 192, 24) 216         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 192, 192, 24) 96          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 192, 192, 24) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 24)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 24)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 6)      150         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 24)     168         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 192, 192, 24) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 192, 192, 24) 576         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 192, 192, 24) 96          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (FixedDropout)     (None, 192, 192, 24) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 192, 192, 24) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 192, 192, 144 3456        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 192, 192, 144 576         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 192, 192, 144 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 96, 96, 144)  1296        block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 96, 96, 144)  576         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 96, 96, 144)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 144)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 96, 96, 144)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 96, 96, 32)   4608        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 96, 96, 32)   128         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 96, 96, 192)  6144        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 96, 96, 192)  768         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 96, 96, 192)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 96, 96, 192)  1728        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 96, 96, 192)  768         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 96, 96, 192)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 192)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 96, 96, 192)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 96, 96, 32)   6144        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 96, 96, 32)   128         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (FixedDropout)     (None, 96, 96, 32)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 96, 96, 32)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 96, 96, 192)  6144        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 96, 96, 192)  768         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 96, 96, 192)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 96, 96, 192)  1728        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 96, 96, 192)  768         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 96, 96, 192)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 192)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 96, 96, 192)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 96, 96, 32)   6144        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 96, 96, 32)   128         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (FixedDropout)     (None, 96, 96, 32)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 96, 96, 32)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 96, 96, 192)  6144        block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 96, 96, 192)  768         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 96, 96, 192)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 48, 48, 192)  4800        block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 48, 48, 192)  768         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 48, 48, 192)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 192)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 48, 48, 192)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 48, 48, 48)   9216        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 48, 48, 48)   192         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 48, 48, 288)  13824       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 48, 48, 288)  1152        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 48, 48, 288)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 48, 48, 288)  7200        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 48, 48, 288)  1152        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 48, 48, 288)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 288)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 48, 48, 288)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 48, 48, 48)   13824       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 48, 48, 48)   192         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (FixedDropout)     (None, 48, 48, 48)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 48, 48, 48)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 48, 48, 288)  13824       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 48, 48, 288)  1152        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 48, 48, 288)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 48, 48, 288)  7200        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 48, 48, 288)  1152        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 48, 48, 288)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 288)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 48, 48, 288)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 48, 48, 48)   13824       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 48, 48, 48)   192         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (FixedDropout)     (None, 48, 48, 48)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 48, 48, 48)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 48, 48, 288)  13824       block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 48, 48, 288)  1152        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 48, 48, 288)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 24, 24, 288)  2592        block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 24, 24, 288)  1152        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 24, 24, 288)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 288)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 24, 24, 288)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 24, 24, 96)   27648       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 24, 24, 96)   384         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 24, 24, 576)  55296       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 24, 24, 576)  2304        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 24, 24, 576)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 24, 24, 576)  5184        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 24, 24, 576)  2304        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 24, 24, 576)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 576)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 24, 24, 576)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 24, 24, 96)   55296       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 24, 24, 96)   384         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (FixedDropout)     (None, 24, 24, 96)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 24, 24, 96)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 24, 24, 576)  55296       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 24, 24, 576)  2304        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 24, 24, 576)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 24, 24, 576)  5184        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 24, 24, 576)  2304        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 24, 24, 576)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 576)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 24, 24, 576)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 24, 24, 96)   55296       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 24, 24, 96)   384         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (FixedDropout)     (None, 24, 24, 96)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 24, 24, 96)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, 24, 24, 576)  55296       block4c_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, 24, 24, 576)  2304        block4d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, 24, 24, 576)  0           block4d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, 24, 24, 576)  5184        block4d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, 24, 24, 576)  2304        block4d_dwconv[0][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, 24, 24, 576)  0           block4d_bn[0][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 576)          0           block4d_activation[0][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, 24, 24, 576)  0           block4d_activation[0][0]
#                                                                  block4d_se_expand[0][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, 24, 24, 96)   55296       block4d_se_excite[0][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, 24, 24, 96)   384         block4d_project_conv[0][0]
# __________________________________________________________________________________________________
# block4d_drop (FixedDropout)     (None, 24, 24, 96)   0           block4d_project_bn[0][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, 24, 24, 96)   0           block4d_drop[0][0]
#                                                                  block4c_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_conv (Conv2D)    (None, 24, 24, 576)  55296       block4d_add[0][0]
# __________________________________________________________________________________________________
# block4e_expand_bn (BatchNormali (None, 24, 24, 576)  2304        block4e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4e_expand_activation (Acti (None, 24, 24, 576)  0           block4e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4e_dwconv (DepthwiseConv2D (None, 24, 24, 576)  5184        block4e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4e_bn (BatchNormalization) (None, 24, 24, 576)  2304        block4e_dwconv[0][0]
# __________________________________________________________________________________________________
# block4e_activation (Activation) (None, 24, 24, 576)  0           block4e_bn[0][0]
# __________________________________________________________________________________________________
# block4e_se_squeeze (GlobalAvera (None, 576)          0           block4e_activation[0][0]
# __________________________________________________________________________________________________
# block4e_se_reshape (Reshape)    (None, 1, 1, 576)    0           block4e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4e_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block4e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4e_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block4e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4e_se_excite (Multiply)    (None, 24, 24, 576)  0           block4e_activation[0][0]
#                                                                  block4e_se_expand[0][0]
# __________________________________________________________________________________________________
# block4e_project_conv (Conv2D)   (None, 24, 24, 96)   55296       block4e_se_excite[0][0]
# __________________________________________________________________________________________________
# block4e_project_bn (BatchNormal (None, 24, 24, 96)   384         block4e_project_conv[0][0]
# __________________________________________________________________________________________________
# block4e_drop (FixedDropout)     (None, 24, 24, 96)   0           block4e_project_bn[0][0]
# __________________________________________________________________________________________________
# block4e_add (Add)               (None, 24, 24, 96)   0           block4e_drop[0][0]
#                                                                  block4d_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 24, 24, 576)  55296       block4e_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 24, 24, 576)  2304        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 24, 24, 576)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 24, 24, 576)  14400       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 24, 24, 576)  2304        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 24, 24, 576)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 576)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 576)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 24)     13848       block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 576)    14400       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 24, 24, 576)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 24, 24, 136)  78336       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 24, 24, 136)  544         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 24, 24, 816)  110976      block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 24, 24, 816)  3264        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 24, 24, 816)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 24, 24, 816)  20400       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 24, 24, 816)  3264        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 24, 24, 816)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 816)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 816)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 34)     27778       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 816)    28560       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 24, 24, 816)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 24, 24, 136)  110976      block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 24, 24, 136)  544         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (FixedDropout)     (None, 24, 24, 136)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 24, 24, 136)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 24, 24, 816)  110976      block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 24, 24, 816)  3264        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 24, 24, 816)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 24, 24, 816)  20400       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 24, 24, 816)  3264        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 24, 24, 816)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 816)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 816)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 34)     27778       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 816)    28560       block5c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 24, 24, 816)  0           block5c_activation[0][0]
#                                                                  block5c_se_expand[0][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, 24, 24, 136)  110976      block5c_se_excite[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 24, 24, 136)  544         block5c_project_conv[0][0]
# __________________________________________________________________________________________________
# block5c_drop (FixedDropout)     (None, 24, 24, 136)  0           block5c_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 24, 24, 136)  0           block5c_drop[0][0]
# ...
# __________________________________________________________________________________________________
# block6f_project_bn (BatchNormal (None, 12, 12, 232)  928         block6f_project_conv[0][0]
# __________________________________________________________________________________________________
# block6f_drop (FixedDropout)     (None, 12, 12, 232)  0           block6f_project_bn[0][0]
# __________________________________________________________________________________________________
# block6f_add (Add)               (None, 12, 12, 232)  0           block6f_drop[0][0]
#                                                                  block6e_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 12, 12, 1392) 322944      block6f_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 12, 12, 1392) 5568        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 12, 12, 1392) 0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 12, 12, 1392) 12528       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 12, 12, 1392) 5568        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 12, 12, 1392) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1392)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1392)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 58)     80794       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1392)   82128       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 12, 12, 1392) 0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 12, 12, 384)  534528      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 12, 12, 384)  1536        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 12, 12, 2304) 884736      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 12, 12, 2304) 9216        block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 12, 12, 2304) 0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 12, 12, 2304) 20736       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 12, 12, 2304) 9216        block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 12, 12, 2304) 0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 2304)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 12, 12, 2304) 0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 12, 12, 384)  884736      block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 12, 12, 384)  1536        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (FixedDropout)     (None, 12, 12, 384)  0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 12, 12, 384)  0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 12, 12, 1536) 589824      block7b_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 12, 12, 1536) 6144        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 12, 12, 1536) 0           top_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsampling (UpSa (None, 24, 24, 1536) 0           top_activation[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_concat (Concaten (None, 24, 24, 2352) 0           decoder_stage0_upsampling[0][0]
#                                                                  block6a_expand_activation[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_conv (Conv2D)   (None, 24, 24, 256)  5419008     decoder_stage0_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_bn (BatchNormal (None, 24, 24, 256)  1024        decoder_stage0a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0a_relu (Activatio (None, 24, 24, 256)  0           decoder_stage0a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_conv (Conv2D)   (None, 24, 24, 256)  589824      decoder_stage0a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_bn (BatchNormal (None, 24, 24, 256)  1024        decoder_stage0b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage0b_relu (Activatio (None, 24, 24, 256)  0           decoder_stage0b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsampling (UpSa (None, 48, 48, 256)  0           decoder_stage0b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_concat (Concaten (None, 48, 48, 544)  0           decoder_stage1_upsampling[0][0]
#                                                                  block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_conv (Conv2D)   (None, 48, 48, 128)  626688      decoder_stage1_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_bn (BatchNormal (None, 48, 48, 128)  512         decoder_stage1a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1a_relu (Activatio (None, 48, 48, 128)  0           decoder_stage1a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_conv (Conv2D)   (None, 48, 48, 128)  147456      decoder_stage1a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_bn (BatchNormal (None, 48, 48, 128)  512         decoder_stage1b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage1b_relu (Activatio (None, 48, 48, 128)  0           decoder_stage1b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsampling (UpSa (None, 96, 96, 128)  0           decoder_stage1b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_concat (Concaten (None, 96, 96, 320)  0           decoder_stage2_upsampling[0][0]
#                                                                  block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_conv (Conv2D)   (None, 96, 96, 64)   184320      decoder_stage2_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_bn (BatchNormal (None, 96, 96, 64)   256         decoder_stage2a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2a_relu (Activatio (None, 96, 96, 64)   0           decoder_stage2a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_conv (Conv2D)   (None, 96, 96, 64)   36864       decoder_stage2a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_bn (BatchNormal (None, 96, 96, 64)   256         decoder_stage2b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage2b_relu (Activatio (None, 96, 96, 64)   0           decoder_stage2b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsampling (UpSa (None, 192, 192, 64) 0           decoder_stage2b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_concat (Concaten (None, 192, 192, 208 0           decoder_stage3_upsampling[0][0]
#                                                                  block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_conv (Conv2D)   (None, 192, 192, 32) 59904       decoder_stage3_concat[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_bn (BatchNormal (None, 192, 192, 32) 128         decoder_stage3a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3a_relu (Activatio (None, 192, 192, 32) 0           decoder_stage3a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_conv (Conv2D)   (None, 192, 192, 32) 9216        decoder_stage3a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_bn (BatchNormal (None, 192, 192, 32) 128         decoder_stage3b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage3b_relu (Activatio (None, 192, 192, 32) 0           decoder_stage3b_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsampling (UpSa (None, 384, 384, 32) 0           decoder_stage3b_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_conv (Conv2D)   (None, 384, 384, 16) 4608        decoder_stage4_upsampling[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_bn (BatchNormal (None, 384, 384, 16) 64          decoder_stage4a_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4a_relu (Activatio (None, 384, 384, 16) 0           decoder_stage4a_bn[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_conv (Conv2D)   (None, 384, 384, 16) 2304        decoder_stage4a_relu[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_bn (BatchNormal (None, 384, 384, 16) 64          decoder_stage4b_conv[0][0]
# __________________________________________________________________________________________________
# decoder_stage4b_relu (Activatio (None, 384, 384, 16) 0           decoder_stage4b_bn[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 384, 384, 1)  145         decoder_stage4b_relu[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, 384, 384, 1)  0           final_conv[0][0]
# ==================================================================================================
# Total params: 17,867,113
# Trainable params: 17,777,833
# Non-trainable params: 89,280
# __________________________________________________________________________________________________

# %%
tensorboard_callback = callbacks.TensorBoard(log_dir="tensor.logs")
best = {"val":-999}
class SaveModelCallBack(callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        self.model.save_weights("models/model.hdf5")
        iou_score = logs.get("iou_score")
        if iou_score > best["val"]:
            best['val'] = iou_score
            model.save_weights("models/weights.hdf5")
            model.save("models/best_model.hdf5")

save_models_callback = SaveModelCallBack()
results = model.fit(train_data,
                    initial_epoch=0,
                    epochs=100,
                    callbacks=[tensorboard_callback,
                               save_models_callback])
# Out:
# /home/hassanrehman/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)
# /home/hassanrehman/anaconda3/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 1/100
#   6/165 [>.............................] - ETA: 2:10 - loss: 0.9476 - iou_score: 0.1546 - f1-score: 0.2637WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1968s vs `on_train_batch_end` time: 0.4138s). Check your callbacks.
# 165/165 [==============================] - 79s 326ms/step - loss: 0.4679 - iou_score: 0.4949 - f1-score: 0.6472
# Epoch 2/100
# 165/165 [==============================] - 55s 330ms/step - loss: 0.2206 - iou_score: 0.7056 - f1-score: 0.8232
# Epoch 3/100
# 165/165 [==============================] - 51s 308ms/step - loss: 0.1745 - iou_score: 0.7604 - f1-score: 0.8597
# Epoch 4/100
# 165/165 [==============================] - 55s 333ms/step - loss: 0.1480 - iou_score: 0.7903 - f1-score: 0.8809
# Epoch 5/100
# 165/165 [==============================] - 51s 308ms/step - loss: 0.1266 - iou_score: 0.8175 - f1-score: 0.8985
# Epoch 6/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.1376 - iou_score: 0.8058 - f1-score: 0.8894
# Epoch 7/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.1100 - iou_score: 0.8399 - f1-score: 0.9119
# Epoch 8/100
# 165/165 [==============================] - 55s 331ms/step - loss: 0.1036 - iou_score: 0.8476 - f1-score: 0.9166
# Epoch 9/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0968 - iou_score: 0.8567 - f1-score: 0.9222
# Epoch 10/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.0932 - iou_score: 0.8642 - f1-score: 0.9241
# Epoch 11/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.0841 - iou_score: 0.8740 - f1-score: 0.9324
# Epoch 12/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0849 - iou_score: 0.8731 - f1-score: 0.9317
# Epoch 13/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0817 - iou_score: 0.8772 - f1-score: 0.9343
# Epoch 14/100
# 165/165 [==============================] - 55s 306ms/step - loss: 0.0743 - iou_score: 0.8875 - f1-score: 0.9402
# Epoch 15/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0696 - iou_score: 0.8943 - f1-score: 0.9440
# Epoch 16/100
# 165/165 [==============================] - 51s 308ms/step - loss: 0.0698 - iou_score: 0.8933 - f1-score: 0.9435
# Epoch 17/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.0675 - iou_score: 0.8969 - f1-score: 0.9455
# Epoch 18/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0662 - iou_score: 0.8988 - f1-score: 0.9465
# Epoch 19/100
# 165/165 [==============================] - 51s 309ms/step - loss: 0.0703 - iou_score: 0.8930 - f1-score: 0.9432
# Epoch 20/100
# 165/165 [==============================] - 52s 311ms/step - loss: 0.0714 - iou_score: 0.8913 - f1-score: 0.9421
# Epoch 21/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0729 - iou_score: 0.8900 - f1-score: 0.9414
# Epoch 22/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.0632 - iou_score: 0.9032 - f1-score: 0.9490
# Epoch 23/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.0704 - iou_score: 0.8926 - f1-score: 0.9429
# Epoch 24/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0628 - iou_score: 0.9034 - f1-score: 0.9491
# Epoch 25/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0566 - iou_score: 0.9125 - f1-score: 0.9542
# Epoch 26/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0558 - iou_score: 0.9138 - f1-score: 0.9549
# Epoch 27/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0632 - iou_score: 0.9032 - f1-score: 0.9489
# Epoch 28/100
# 165/165 [==============================] - 50s 304ms/step - loss: 0.0596 - iou_score: 0.9086 - f1-score: 0.9519
# Epoch 29/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0582 - iou_score: 0.9104 - f1-score: 0.9529
# Epoch 30/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0566 - iou_score: 0.9130 - f1-score: 0.9543
# Epoch 31/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0512 - iou_score: 0.9207 - f1-score: 0.9586
# Epoch 32/100
# 165/165 [==============================] - 51s 308ms/step - loss: 0.0542 - iou_score: 0.9161 - f1-score: 0.9562
# Epoch 33/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.0527 - iou_score: 0.9184 - f1-score: 0.9574
# Epoch 34/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.0733 - iou_score: 0.8904 - f1-score: 0.9411
# Epoch 35/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.0695 - iou_score: 0.8950 - f1-score: 0.9441
# Epoch 36/100
# 165/165 [==============================] - 50s 304ms/step - loss: 0.0541 - iou_score: 0.9165 - f1-score: 0.9562
# Epoch 37/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0572 - iou_score: 0.9122 - f1-score: 0.9538
# Epoch 38/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0651 - iou_score: 0.9003 - f1-score: 0.9473
# Epoch 39/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0566 - iou_score: 0.9126 - f1-score: 0.9542
# Epoch 40/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0505 - iou_score: 0.9220 - f1-score: 0.9593
# Epoch 41/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0469 - iou_score: 0.9270 - f1-score: 0.9621
# Epoch 42/100
# 165/165 [==============================] - 50s 304ms/step - loss: 0.0461 - iou_score: 0.9281 - f1-score: 0.9626
# Epoch 43/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0444 - iou_score: 0.9307 - f1-score: 0.9641
# Epoch 44/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0488 - iou_score: 0.9241 - f1-score: 0.9604
# Epoch 45/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0537 - iou_score: 0.9175 - f1-score: 0.9566
# Epoch 46/100
# 165/165 [==============================] - 51s 310ms/step - loss: 0.0446 - iou_score: 0.9305 - f1-score: 0.9639
# Epoch 47/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0427 - iou_score: 0.9333 - f1-score: 0.9655
# Epoch 48/100
# 165/165 [==============================] - 52s 313ms/step - loss: 0.0405 - iou_score: 0.9367 - f1-score: 0.9673
# Epoch 49/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.0397 - iou_score: 0.9380 - f1-score: 0.9680
# Epoch 50/100
# 165/165 [==============================] - 55s 329ms/step - loss: 0.0392 - iou_score: 0.9386 - f1-score: 0.9683
# Epoch 51/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0398 - iou_score: 0.9378 - f1-score: 0.9678
# Epoch 52/100
# 165/165 [==============================] - 52s 313ms/step - loss: 0.0383 - iou_score: 0.9400 - f1-score: 0.9690
# Epoch 53/100
# 165/165 [==============================] - 51s 308ms/step - loss: 0.0400 - iou_score: 0.9373 - f1-score: 0.9676
# Epoch 54/100
# 165/165 [==============================] - 50s 304ms/step - loss: 0.0382 - iou_score: 0.9403 - f1-score: 0.9692
# Epoch 55/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0368 - iou_score: 0.9422 - f1-score: 0.9702
# Epoch 56/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0443 - iou_score: 0.9312 - f1-score: 0.9643
# Epoch 57/100
# 165/165 [==============================] - 50s 304ms/step - loss: 0.0454 - iou_score: 0.9294 - f1-score: 0.9633
# Epoch 58/100
# 165/165 [==============================] - 50s 303ms/step - loss: 0.0512 - iou_score: 0.9207 - f1-score: 0.9586
# Epoch 59/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0393 - iou_score: 0.9386 - f1-score: 0.9683
# Epoch 60/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0367 - iou_score: 0.9425 - f1-score: 0.9703
# Epoch 61/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0371 - iou_score: 0.9419 - f1-score: 0.9700
# Epoch 62/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0351 - iou_score: 0.9450 - f1-score: 0.9717
# Epoch 63/100
# 165/165 [==============================] - 50s 304ms/step - loss: 0.0351 - iou_score: 0.9450 - f1-score: 0.9717
# Epoch 64/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0322 - iou_score: 0.9496 - f1-score: 0.9741
# Epoch 65/100
# 165/165 [==============================] - 51s 304ms/step - loss: 0.0455 - iou_score: 0.9304 - f1-score: 0.9636
# Epoch 66/100
# 165/165 [==============================] - 50s 304ms/step - loss: 0.0384 - iou_score: 0.9399 - f1-score: 0.9690
# Epoch 67/100
# 165/165 [==============================] - 51s 310ms/step - loss: 0.0418 - iou_score: 0.9350 - f1-score: 0.9663
# Epoch 68/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0375 - iou_score: 0.9415 - f1-score: 0.9698
# Epoch 69/100
# 165/165 [==============================] - 51s 304ms/step - loss: 0.0343 - iou_score: 0.9464 - f1-score: 0.9724
# Epoch 70/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0330 - iou_score: 0.9483 - f1-score: 0.9734
# Epoch 71/100
# 165/165 [==============================] - 51s 309ms/step - loss: 0.0439 - iou_score: 0.9323 - f1-score: 0.9647
# Epoch 72/100
# 165/165 [==============================] - 51s 310ms/step - loss: 0.0348 - iou_score: 0.9454 - f1-score: 0.9719
# Epoch 73/100
# 165/165 [==============================] - 51s 309ms/step - loss: 0.0312 - iou_score: 0.9512 - f1-score: 0.9749
# Epoch 74/100
# 165/165 [==============================] - 51s 308ms/step - loss: 0.0301 - iou_score: 0.9528 - f1-score: 0.9758
# Epoch 75/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.0297 - iou_score: 0.9533 - f1-score: 0.9761
# Epoch 76/100
# 165/165 [==============================] - 51s 308ms/step - loss: 0.0285 - iou_score: 0.9552 - f1-score: 0.9771
# Epoch 77/100
# 165/165 [==============================] - 51s 309ms/step - loss: 0.0391 - iou_score: 0.9397 - f1-score: 0.9685
# Epoch 78/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0363 - iou_score: 0.9434 - f1-score: 0.9708
# Epoch 79/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0314 - iou_score: 0.9507 - f1-score: 0.9747
# Epoch 80/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0324 - iou_score: 0.9493 - f1-score: 0.9739
# Epoch 81/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0279 - iou_score: 0.9561 - f1-score: 0.9775
# Epoch 82/100
# 165/165 [==============================] - 59s 358ms/step - loss: 0.0265 - iou_score: 0.9584 - f1-score: 0.9787
# Epoch 83/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0254 - iou_score: 0.9601 - f1-score: 0.9796
# Epoch 84/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0266 - iou_score: 0.9581 - f1-score: 0.9786
# Epoch 85/100
# 165/165 [==============================] - 52s 311ms/step - loss: 0.0414 - iou_score: 0.9359 - f1-score: 0.9667
# Epoch 86/100
# 165/165 [==============================] - 51s 310ms/step - loss: 0.0309 - iou_score: 0.9515 - f1-score: 0.9751
# Epoch 87/100
# 165/165 [==============================] - 50s 304ms/step - loss: 0.0275 - iou_score: 0.9566 - f1-score: 0.9778
# Epoch 88/100
# 165/165 [==============================] - 51s 305ms/step - loss: 0.0258 - iou_score: 0.9594 - f1-score: 0.9793
# Epoch 89/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0264 - iou_score: 0.9584 - f1-score: 0.9787
# Epoch 90/100
# 165/165 [==============================] - 51s 308ms/step - loss: 0.0244 - iou_score: 0.9615 - f1-score: 0.9803
# Epoch 91/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.0250 - iou_score: 0.9605 - f1-score: 0.9798
# Epoch 92/100
# 165/165 [==============================] - 51s 308ms/step - loss: 0.0237 - iou_score: 0.9626 - f1-score: 0.9809
# Epoch 93/100
# 165/165 [==============================] - 51s 308ms/step - loss: 0.0280 - iou_score: 0.9568 - f1-score: 0.9777
# Epoch 94/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.0286 - iou_score: 0.9552 - f1-score: 0.9771
# Epoch 95/100
# 165/165 [==============================] - 51s 306ms/step - loss: 0.0257 - iou_score: 0.9595 - f1-score: 0.9793
# Epoch 96/100
# 165/165 [==============================] - 50s 304ms/step - loss: 0.0248 - iou_score: 0.9611 - f1-score: 0.9801
# Epoch 97/100
# 165/165 [==============================] - 52s 314ms/step - loss: 0.0266 - iou_score: 0.9581 - f1-score: 0.9785
# Epoch 98/100
# 165/165 [==============================] - 51s 309ms/step - loss: 0.0261 - iou_score: 0.9589 - f1-score: 0.9790
# Epoch 99/100
# 165/165 [==============================] - 51s 308ms/step - loss: 0.0256 - iou_score: 0.9601 - f1-score: 0.9795
# Epoch 100/100
# 165/165 [==============================] - 51s 304ms/step - loss: 0.0338 - iou_score: 0.9473 - f1-score: 0.9728
